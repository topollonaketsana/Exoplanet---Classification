# %%
import os              
import pandas as pd   
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.linear_model import LogisticRegression
from zlib import crc32

# %%
print("Current Working Directory:", os.getcwd())

DATA_PATH = "../data/"
FILE_NAME = "exoplanets.csv"
FULL_PATH = os.path.join(DATA_PATH, FILE_NAME)
exoplanets = pd.read_csv (FULL_PATH, thousands = ',')

exoplanets.head ()
# Out:
# Current Working Directory: c:\Users\topol\Exoplanet---Classification\docs
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# 0      1.000              0              0              0  ...
# 1      0.969              0              0              0  ...
# 2      0.000              0              1              0  ...
# 3      0.000              0              1              0  ...
# 4      1.000              0              0              0  ...
#
# ...

# %% [markdown]
# ### To see whether data is numerical or not, and to understand it better:

# %%
exoplanets.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 50 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              9564 non-null   int64
#  1   kepid              9564 non-null   int64
#  2   kepoi_name         9564 non-null   object
#  3   kepler_name        2294 non-null   object
#  4   koi_disposition    9564 non-null   object
#  5   koi_pdisposition   9564 non-null   object
#  6   koi_score          8054 non-null   float64
#  7   koi_fpflag_nt      9564 non-null   int64
#  8   koi_fpflag_ss      9564 non-null   int64
#  9   koi_fpflag_co      9564 non-null   int64
#  10  koi_fpflag_ec      9564 non-null   int64
#  11  koi_period         9564 non-null   float64
#  12  koi_period_err1    9110 non-null   float64
#  13  koi_period_err2    9110 non-null   float64
#  14  koi_time0bk        9564 non-null   float64
#  15  koi_time0bk_err1   9110 non-null   float64
# ...

# %% [markdown]
# #### I will use describe () fuction to show a summary of numerical attributes

# %%
exoplanets.describe ()
# Out:
#              rowid         kepid    koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# count  9564.000000  9.564000e+03  8054.000000    9564.000000    9564.000000
# mean   4782.500000  7.690628e+06     0.480829       0.188206       0.231598
# std    2761.033321  2.653459e+06     0.476928       0.390897       0.421875
# min       1.000000  7.574500e+05     0.000000       0.000000       0.000000
# 25%    2391.750000  5.556034e+06     0.000000       0.000000       0.000000
# 50%    4782.500000  7.906892e+06     0.334000       0.000000       0.000000
# 75%    7173.250000  9.873066e+06     0.998000       0.000000       0.000000
# max    9564.000000  1.293514e+07     1.000000       1.000000       1.000000
#
#        koi_fpflag_co  koi_fpflag_ec     koi_period  koi_period_err1  \
# count    9564.000000    9564.000000    9564.000000      9110.000000
# mean        0.194898       0.120033      75.671358         0.002148
# std         0.396143       0.325018    1334.744046         0.008236
# ...

# %% [markdown]
# ### Data Splitting

# %% [markdown]
# #### Lets divide dataset into training and create test set

# %% [markdown]
# #####  before diving into data spliting we should remove all irrelevant features from our data, such as kepler_name, id/index, and so on. This is for the model simplicity

# %%
X = exoplanets.drop (['rowid', 'koi_disposition', 'kepid', 'kepler_name', 'kepoi_name'], axis = 1)

X.head ()
# Out:
#   koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0        CANDIDATE      1.000              0              0              0
# 1        CANDIDATE      0.969              0              0              0
# 2   FALSE POSITIVE      0.000              0              1              0
# 3   FALSE POSITIVE      0.000              0              1              0
# 4        CANDIDATE      1.000              0              0              0
#
#    koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0              0    9.488036     2.775000e-05    -2.775000e-05   170.538750
# 1              0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 2              0   19.899140     1.494000e-05    -1.494000e-05   175.850252
# 3              0    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 4              0    2.525592     3.761000e-06    -3.761000e-06   171.595550
#
# ...

# %% [markdown]
# #### For our Test set, we will fix random seed and allow the dataset to split into training and test sets. 20% of the data will be used for testing and the split function will be reproducible because of the random state chosen.

# %%
X = exoplanets.drop (['rowid', 'koi_disposition', 'kepid', 'kepler_name', 'kepoi_name'], axis = 1)
X_train, X_test = train_test_split (X, test_size = 0.2, random_state = 27)

# %% [markdown]
# #### We can see that `koi_pdisposition` is a catagorical attribute and it is our target column since it is repetition of  `false positive` and `candidade`. To count how many objects belong to each catagory:

# %%
exoplanets["koi_pdisposition"].value_counts ()
# Out:
# koi_pdisposition
# FALSE POSITIVE    5068
# CANDIDATE         4496
# Name: count, dtype: int64

# %%
X ["koi_pdisposition"].value_counts ()
# Out:
# koi_pdisposition
# FALSE POSITIVE    5068
# CANDIDATE         4496
# Name: count, dtype: int64

# %% [markdown]
# #### Counts are the same for both modified DataFrame and non-modified DataFrame

# %% [markdown]
# ##

# %%
# Lets look at summary of the numerical attributes from dataframe X
X.describe ()
# Out:
#          koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# count  8054.000000    9564.000000    9564.000000    9564.000000
# mean      0.480829       0.188206       0.231598       0.194898
# std       0.476928       0.390897       0.421875       0.396143
# min       0.000000       0.000000       0.000000       0.000000
# 25%       0.000000       0.000000       0.000000       0.000000
# 50%       0.334000       0.000000       0.000000       0.000000
# 75%       0.998000       0.000000       0.000000       0.000000
# max       1.000000       1.000000       1.000000       1.000000
#
#        koi_fpflag_ec     koi_period  koi_period_err1  koi_period_err2  \
# count    9564.000000    9564.000000      9110.000000      9110.000000
# mean        0.120033      75.671358         0.002148        -0.002148
# std         0.325018    1334.744046         0.008236         0.008236
# min         0.000000       0.241843         0.000000        -0.172500
# ...

# %% [markdown]
# #### We can use histogram plots for each numerical attribute, hist will show number of instances (on vertical axis) and given value range (on horizontal axis).

# %%
#column = ['koi_fpflag_nt', 'koi_period', 'koi_kepmag', 'ra', 'koi_slogg', 'koi_srad']
X ['koi_period'].hist (bins = 7, figsize = (8, 8))
plt.xlabel ("koi_period")
plt.ylabel ("count")
plt.show ()
